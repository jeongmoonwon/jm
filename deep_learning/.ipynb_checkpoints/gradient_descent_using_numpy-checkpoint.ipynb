# %%
import numpy as np
import time
import random
import matplotlib.pyplot as plt

# %%
# ----- Gradient Descent Implementation -----

# %%
class SampleModel:
    """ class for sample model with parameters a,b """
    
    def __init__(self, a=0.5, b=0.5):
        """
        Initialize coefficient and bias

        Inputs:
        - a: coef
        - b: bias
        """
        self.params = {'coef':a, 'bias':b}

    def data_generation(self, true_a, true_b):
        """
        Generate dataset
        """
        self.true_a = true_a
        self.true_b = true_b

        N = 100000

        X = np.random.randn(N)
        random_noise = np.random.randn(N) / 10

        X_modified = X + random_noise

        y = self.true_a*X_modified + self.true_b

        return X, y

    def data_generation_quad(self, true_a, true_b):
        """
        Generate dataset
        """
        self.true_a = true_a
        self.true_b = true_b

        N = 100000

        X = np.random.randn(N)
        random_noise = np.random.randn(N) / 10

        X_modified = X + random_noise

        y = np.power(self.true_a*X_modified + self.true_b, 2)

        return X, y

    def forward(self, X):
        """
        Implement forward pass for the model
        """
        a, b = self.params['coef'], self.params['bias']
        y = a * X + b
        return y

    def backward(self, X, y):
        """
        Computes the gradients for each param in self.params
        @param X: training input data (N,)
        @param y: training output data (N,)
        @return: gradients of parameters
        """
        a, b = self.params['coef'], self.params['bias']

        gradients = {}     ## Loss(L2) = avg((y - (a*X + b))^2)
        gradients['coef'] = np.mean(2*(y - (a*X+b))*(-X))
        gradients['bias']  = np.mean(2*(y - (a*X+b))*(-1))

        return gradients

    def run(self, X, y, train=False, n_epochs=10, lr=0.001, batch_size=None):
        """
        Runs the model with training as an option.
        @param X: training input data (N,)
        @param y: training output data (N,)
        @train: boolean for train
        @n_epochs: number of traninig epochs
        @lr: learning rate
        """
        print("Training Starts...")
        if train:
            if batch_size:
                print("Mini-Batch SGD w Batch Size: {}".format(batch_size))
                self.batch_gradient_descent(X, y, n_epochs=n_epochs, lr=lr, batch_size=batch_size)
            
            else:
                print("Full-Batch GD")
                self.gradient_descent(X, y, n_epochs=n_epochs, lr=lr)

    def gradient_descent(self, X, y, n_epochs=10, lr=0.001):
        """
        Train using batch gradient descent.
        @param X: training input data (N,)
        @param y: training output data (N,)
        @param lr: learning rate
        """
        loss_list = []
        first = 100000000
        
        for epoch in range(n_epochs):
            gradients = self.backward(X, y)
            for param in self.params:
                self.params[param] -= lr * gradients[param]
            
            # 연속되는 epoch 간 loss difference를 계산하고 loss의 변화를 기록하기 위한 코드를 추가함
            second = self.compute_loss(X,y)
            diff = (first - second) / first
            first = second
            loss_list.append(second)
        
            print("========== Epoch {}/{} ==========".format(epoch+1, n_epochs))
            print("Loss > {:.15f}".format(self.compute_loss(X,y)))
            print("Params > coef: {:.2f} / bias: {:.2f}".format(self.params['coef'], self.params['bias']))
            print("Loss Difference between Successive Epochs:",round(diff*100,3),"%")
            
            if diff < 0.01 and diff > -0.01:
                break
        plt.plot(loss_list, marker='o')
        plt.title('Full-Batch GD')
        plt.xlabel('Epoch')
        plt.ylabel('Loss Value')
        plt.show()

    def batch_gradient_descent(self, X, y, n_epochs=10, lr=0.001, batch_size=16):
        """
        Train using batch gradient descent.
        @param X: training input data (N,)
        @param y: training output data (N,)
        @param lr: learning rate
        @param batch_size
        """
        first = 100000000
        loss_list = []
        
        for epoch in range(n_epochs):
            
            # batch size만큼 뽑기
            random_idxs = np.random.choice(np.size(X), batch_size)
            X_new = X[random_idxs]
            y_new = y[random_idxs]
                
            # gradient 구하기
            gradients = self.backward(X_new, y_new)
                
            # parameter 업데이트
            for param in self.params:
                self.params[param] -= lr * gradients[param]
            
            # 연속되는 epoch 간 loss difference를 계산하고 loss의 변화를 기록하기 위한 코드를 추가함
            second = self.compute_loss(X,y)
            diff = (first - second) / first
            first = second
            loss_list.append(second)
            
            print("========== Epoch {}/{} ==========".format(epoch+1, n_epochs))
            print("Loss > {:.10f}".format(self.compute_loss(X,y)))
            print("Params > coef: {:.2f} / bias: {:.2f}".format(self.params['coef'], self.params['bias']))
            print("Loss Difference between Successive Epochs:",round(diff*100,3),"%")
        
            if diff < 0.01 and diff > -0.01:
                break
        
        plt.plot(loss_list, marker='o')
        plt.title('SGD')
        plt.xlabel('Epoch')
        plt.ylabel('Loss Value')
        plt.show()
            
            
    def compute_loss(self, X, y):
        """
        Computes the L2 loss of the model given X, y.
        @param X: training input data (N,)
        @param y: training output data (N,)
        @return: loss
        """
        a, b = self.params['coef'], self.params['bias']
        loss = np.mean(np.power(y - (a*X + b), 2))
        return loss

# %%
# ----- Test Full-Batch GD -----

# %%
model = SampleModel(a=0.5, b=0.5)

# %%
# Test 1
X, y = model.data_generation(true_a=20, true_b=5)

n_epochs, lr = 100, 1e-1

start_time = time.time()

model.run(X, y, train=True, n_epochs=n_epochs, lr=lr)
loss = model.compute_loss(X, y)

end_time = time.time()

print("Training Ends...")
print()
print("Trained with {} epochs, {} learning rate".format(n_epochs, lr))
print("Time Cost: {:.5f} sec".format(end_time-start_time))
# Out:
# Training Starts...
# Full-Batch GD
# ========== Epoch 1/100 ==========
# Loss > 260.532519922798372
# Params > coef: 4.40 / bias: 1.40
# Loss Difference between Successive Epochs: 100.0 %
# ========== Epoch 2/100 ==========
# Loss > 168.095098480535256
# Params > coef: 7.53 / bias: 2.12
# Loss Difference between Successive Epochs: 35.48 %
# ========== Epoch 3/100 ==========
# Loss > 108.966838324159127
# Params > coef: 10.03 / bias: 2.70
# Loss Difference between Successive Epochs: 35.175 %
# ========== Epoch 4/100 ==========
# Loss > 71.145022260816745
# Params > coef: 12.02 / bias: 3.16
# Loss Difference between Successive Epochs: 34.709 %
# ========== Epoch 5/100 ==========
# Loss > 46.952026096533018
# Params > coef: 13.62 / bias: 3.53
# Loss Difference between Successive Epochs: 34.005 %
# ========== Epoch 6/100 ==========
# Loss > 31.476802411702163
# Params > coef: 14.90 / bias: 3.82
# Loss Difference between Successive Epochs: 32.96 %
# ========== Epoch 7/100 ==========
# Loss > 21.577964474919895
# Params > coef: 15.92 / bias: 4.06
# Loss Difference between Successive Epochs: 31.448 %
# ========== Epoch 8/100 ==========
# Loss > 15.246101714706743
# Params > coef: 16.74 / bias: 4.25
# Loss Difference between Successive Epochs: 29.344 %
# ========== Epoch 9/100 ==========
# Loss > 11.195880234805221
# Params > coef: 17.39 / bias: 4.40
# Loss Difference between Successive Epochs: 26.566 %
# ========== Epoch 10/100 ==========
# Loss > 8.605126981444815
# Params > coef: 17.91 / bias: 4.52
# Loss Difference between Successive Epochs: 23.14 %
# ========== Epoch 11/100 ==========
# Loss > 6.947933058338627
# Params > coef: 18.33 / bias: 4.62
# Loss Difference between Successive Epochs: 19.258 %
# ========== Epoch 12/100 ==========
# Loss > 5.887897064240554
# Params > coef: 18.67 / bias: 4.69
# Loss Difference between Successive Epochs: 15.257 %
# ========== Epoch 13/100 ==========
# Loss > 5.209837427541020
# Params > coef: 18.93 / bias: 4.76
# Loss Difference between Successive Epochs: 11.516 %
# ========== Epoch 14/100 ==========
# Loss > 4.776111710913922
# Params > coef: 19.15 / bias: 4.81
# Loss Difference between Successive Epochs: 8.325 %
# ========== Epoch 15/100 ==========
# Loss > 4.498675940972307
# Params > coef: 19.32 / bias: 4.85
# Loss Difference between Successive Epochs: 5.809 %
# ========== Epoch 16/100 ==========
# Loss > 4.321212157900256
# Params > coef: 19.46 / bias: 4.88
# Loss Difference between Successive Epochs: 3.945 %
# ========== Epoch 17/100 ==========
# Loss > 4.207696174264223
# Params > coef: 19.56 / bias: 4.90
# Loss Difference between Successive Epochs: 2.627 %
# ========== Epoch 18/100 ==========
# Loss > 4.135084859857625
# Params > coef: 19.65 / bias: 4.92
# Loss Difference between Successive Epochs: 1.726 %
# ========== Epoch 19/100 ==========
# Loss > 4.088638510946452
# Params > coef: 19.72 / bias: 4.94
# Loss Difference between Successive Epochs: 1.123 %
# ========== Epoch 20/100 ==========
# Loss > 4.058928770170135
# Params > coef: 19.78 / bias: 4.95
# Loss Difference between Successive Epochs: 0.727 %
# Training Ends...
#
# Trained with 100 epochs, 0.1 learning rate
# Time Cost: 0.30314 sec

# %%
# Test 2
X, y = model.data_generation_quad(true_a=20, true_b=5)

n_epochs, lr = 100, 1e-1

start_time = time.time()

model.run(X, y, train=True, n_epochs=n_epochs, lr=lr)
loss = model.compute_loss(X, y)

end_time = time.time()

print("Training Ends...")
print()
print("Trained with {} epochs, {} learning rate".format(n_epochs, lr))
print("Time Cost: {:.5f} sec".format(end_time-start_time))
# Out:
# Training Starts...
# Full-Batch GD
# ========== Epoch 1/100 ==========
# Loss > 458589.377513077226467
# Params > coef: 54.33 / bias: 89.42
# Loss Difference between Successive Epochs: 99.541 %
# ========== Epoch 2/100 ==========
# Loss > 410541.394070804875810
# Params > coef: 82.04 / bias: 157.01
# Loss Difference between Successive Epochs: 10.477 %
# ========== Epoch 3/100 ==========
# Loss > 379750.870595966931432
# Params > coef: 104.26 / bias: 211.11
# Loss Difference between Successive Epochs: 7.5 %
# ========== Epoch 4/100 ==========
# Loss > 360019.375192601641174
# Params > coef: 122.09 / bias: 254.40
# Loss Difference between Successive Epochs: 5.196 %
# ========== Epoch 5/100 ==========
# Loss > 347374.808594445174094
# Params > coef: 136.38 / bias: 289.04
# Loss Difference between Successive Epochs: 3.512 %
# ========== Epoch 6/100 ==========
# Loss > 339271.751228924491443
# Params > coef: 147.85 / bias: 316.77
# Loss Difference between Successive Epochs: 2.333 %
# ========== Epoch 7/100 ==========
# Loss > 334079.031351546873339
# Params > coef: 157.04 / bias: 338.96
# Loss Difference between Successive Epochs: 1.531 %
# ========== Epoch 8/100 ==========
# Loss > 330751.348785525246058
# Params > coef: 164.42 / bias: 356.71
# Loss Difference between Successive Epochs: 0.996 %
# Training Ends...
#
# Trained with 100 epochs, 0.1 learning rate
# Time Cost: 0.18855 sec

# %%
# ----- Test SGD -----
# batch size가 1로 매우 작기 때문에 loss가 일정하게 줄어들지는 않는다.

# %%
model = SampleModel(a=0.5, b=0.5)

# %%
# Test 1
X, y = model.data_generation(true_a=20, true_b=5)

n_epochs, lr, batch_size = 100, 1e-1, 1

start_time = time.time()

model.run(X, y, train=True, n_epochs=n_epochs, lr=lr, batch_size=batch_size)
loss = model.compute_loss(X, y)

end_time = time.time()

print("Training Ends...")
print()
print("Trained with {} epochs, {} learning rate".format(n_epochs, lr))
print("Time Cost: {:.5f} sec".format(end_time-start_time))
# Out:
# Training Starts...
# Mini-Batch SGD w Batch Size: 1
# ========== Epoch 1/100 ==========
# Loss > 193.0898319749
# Params > coef: 6.28 / bias: 5.84
# Loss Difference between Successive Epochs: 100.0 %
# ========== Epoch 2/100 ==========
# Loss > 49.2826496597
# Params > coef: 19.73 / bias: 11.73
# Loss Difference between Successive Epochs: 74.477 %
# ========== Epoch 3/100 ==========
# Loss > 29.4656105037
# Params > coef: 19.68 / bias: 10.04
# Loss Difference between Successive Epochs: 40.211 %
# ========== Epoch 4/100 ==========
# Loss > 23.7888094019
# Params > coef: 18.53 / bias: 9.20
# Loss Difference between Successive Epochs: 19.266 %
# ========== Epoch 5/100 ==========
# Loss > 15.3054294089
# Params > coef: 19.14 / bias: 8.25
# Loss Difference between Successive Epochs: 35.661 %
# ========== Epoch 6/100 ==========
# Loss > 12.5974616561
# Params > coef: 19.67 / bias: 7.91
# Loss Difference between Successive Epochs: 17.693 %
# ========== Epoch 7/100 ==========
# Loss > 12.3761051273
# Params > coef: 19.62 / bias: 7.87
# Loss Difference between Successive Epochs: 1.757 %
# ========== Epoch 8/100 ==========
# Loss > 10.9966132162
# Params > coef: 21.82 / bias: 6.94
# Loss Difference between Successive Epochs: 11.146 %
# ========== Epoch 9/100 ==========
# Loss > 4.3540463508
# Params > coef: 20.20 / bias: 5.56
# Loss Difference between Successive Epochs: 60.406 %
# ========== Epoch 10/100 ==========
# Loss > 4.7371703997
# Params > coef: 20.38 / bias: 5.78
# Loss Difference between Successive Epochs: -8.799 %
# ========== Epoch 11/100 ==========
# Loss > 4.6006201971
# Params > coef: 20.30 / bias: 5.72
# Loss Difference between Successive Epochs: 2.883 %
# ========== Epoch 12/100 ==========
# Loss > 4.5891711065
# Params > coef: 20.74 / bias: 5.26
# Loss Difference between Successive Epochs: 0.249 %
# Training Ends...
#
# Trained with 100 epochs, 0.1 learning rate
# Time Cost: 0.20339 sec

# %%
# Test 2
X, y = model.data_generation_quad(true_a=20, true_b=5)

n_epochs, lr, batch_size = 100, 1e-1, 1

start_time = time.time()

model.run(X, y, train=True, n_epochs=n_epochs, lr=lr, batch_size=batch_size)
loss = model.compute_loss(X, y)

end_time = time.time()

print("Training Ends...")
print()
print("Trained with {} epochs, {} learning rate".format(n_epochs, lr))
print("Time Cost: {:.5f} sec".format(end_time-start_time))
# Out:
# Training Starts...
# Mini-Batch SGD w Batch Size: 1
# ========== Epoch 1/100 ==========
# Loss > 491470.2248492555
# Params > coef: -1.61 / bias: 69.01
# Loss Difference between Successive Epochs: 99.509 %
# ========== Epoch 2/100 ==========
# Loss > 454128.5439796337
# Params > coef: 20.54 / bias: 112.05
# Loss Difference between Successive Epochs: 7.598 %
# ========== Epoch 3/100 ==========
# Loss > 395398.7612388755
# Params > coef: 74.91 / bias: 188.49
# Loss Difference between Successive Epochs: 12.932 %
# ========== Epoch 4/100 ==========
# Loss > 404016.8121142362
# Params > coef: 88.01 / bias: 165.26
# Loss Difference between Successive Epochs: -2.18 %
# ========== Epoch 5/100 ==========
# Loss > 569921.8923521158
# Params > coef: 694.14 / bias: 477.53
# Loss Difference between Successive Epochs: -41.064 %
# ========== Epoch 6/100 ==========
# Loss > 544795.4006608303
# Params > coef: 662.44 / bias: 516.62
# Loss Difference between Successive Epochs: 4.409 %
# ========== Epoch 7/100 ==========
# Loss > 461453.5085822370
# Params > coef: 569.11 / bias: 387.11
# Loss Difference between Successive Epochs: 15.298 %
# ========== Epoch 8/100 ==========
# Loss > 940636.5455456753
# Params > coef: -453.77 / bias: 864.75
# Loss Difference between Successive Epochs: -103.842 %
# ========== Epoch 9/100 ==========
# Loss > 629771.8387822935
# Params > coef: -311.83 / bias: 642.40
# Loss Difference between Successive Epochs: 33.048 %
# ========== Epoch 10/100 ==========
# Loss > 465939.4811318269
# Params > coef: -165.50 / bias: 530.28
# Loss Difference between Successive Epochs: 26.015 %
# ========== Epoch 11/100 ==========
# Loss > 436451.0436300696
# Params > coef: -138.47 / bias: 416.41
# Loss Difference between Successive Epochs: 6.329 %
# ========== Epoch 12/100 ==========
# Loss > 434572.9917615056
# Params > coef: -120.66 / bias: 327.60
# Loss Difference between Successive Epochs: 0.43 %
# Training Ends...
#
# Trained with 100 epochs, 0.1 learning rate
# Time Cost: 0.18021 sec

# %%
# ----- Test Mini-Batch SGD -----

# %%
model = SampleModel(a=0.5, b=0.5)

# %%
# Test 1
X, y = model.data_generation(true_a=20, true_b=5)

n_epochs, lr, batch_size = 100, 1e-1, 1000

start_time = time.time()

model.run(X, y, train=True, n_epochs=n_epochs, lr=lr, batch_size=batch_size)
loss = model.compute_loss(X, y)

end_time = time.time()

print("Training Ends...")
print()
print("Trained with {} epochs, {} learning rate".format(n_epochs, lr))
print("Time Cost: {:.5f} sec".format(end_time-start_time))
# Out:
# Training Starts...
# Mini-Batch SGD w Batch Size: 1000
# ========== Epoch 1/100 ==========
# Loss > 256.9657529093
# Params > coef: 4.44 / bias: 1.43
# Loss Difference between Successive Epochs: 100.0 %
# ========== Epoch 2/100 ==========
# Loss > 166.2478607849
# Params > coef: 7.55 / bias: 2.08
# Loss Difference between Successive Epochs: 35.303 %
# ========== Epoch 3/100 ==========
# Loss > 106.7839333336
# Params > coef: 10.10 / bias: 2.65
# Loss Difference between Successive Epochs: 35.768 %
# ========== Epoch 4/100 ==========
# Loss > 70.0854040255
# Params > coef: 12.07 / bias: 3.08
# Loss Difference between Successive Epochs: 34.367 %
# ========== Epoch 5/100 ==========
# Loss > 46.9571381469
# Params > coef: 13.59 / bias: 3.49
# Loss Difference between Successive Epochs: 33.0 %
# ========== Epoch 6/100 ==========
# Loss > 30.2264906899
# Params > coef: 14.99 / bias: 3.80
# Loss Difference between Successive Epochs: 35.63 %
# ========== Epoch 7/100 ==========
# Loss > 20.9780076461
# Params > coef: 15.97 / bias: 4.03
# Loss Difference between Successive Epochs: 30.597 %
# ========== Epoch 8/100 ==========
# Loss > 14.8890892968
# Params > coef: 16.76 / bias: 4.24
# Loss Difference between Successive Epochs: 29.025 %
# ========== Epoch 9/100 ==========
# Loss > 11.3001580883
# Params > coef: 17.34 / bias: 4.38
# Loss Difference between Successive Epochs: 24.104 %
# ========== Epoch 10/100 ==========
# Loss > 8.8150077438
# Params > coef: 17.83 / bias: 4.51
# Loss Difference between Successive Epochs: 21.992 %
# ========== Epoch 11/100 ==========
# Loss > 7.1290299612
# Params > coef: 18.24 / bias: 4.62
# Loss Difference between Successive Epochs: 19.126 %
# ========== Epoch 12/100 ==========
# Loss > 5.9785205513
# Params > coef: 18.59 / bias: 4.71
# Loss Difference between Successive Epochs: 16.138 %
# ========== Epoch 13/100 ==========
# Loss > 5.2334835986
# Params > coef: 18.88 / bias: 4.75
# Loss Difference between Successive Epochs: 12.462 %
# ========== Epoch 14/100 ==========
# Loss > 4.8002894266
# Params > coef: 19.09 / bias: 4.79
# Loss Difference between Successive Epochs: 8.277 %
# ========== Epoch 15/100 ==========
# Loss > 4.4897051695
# Params > coef: 19.28 / bias: 4.82
# Loss Difference between Successive Epochs: 6.47 %
# ========== Epoch 16/100 ==========
# Loss > 4.3248538109
# Params > coef: 19.40 / bias: 4.87
# Loss Difference between Successive Epochs: 3.672 %
# ========== Epoch 17/100 ==========
# Loss > 4.2007193392
# Params > coef: 19.51 / bias: 4.90
# Loss Difference between Successive Epochs: 2.87 %
# ========== Epoch 18/100 ==========
# Loss > 4.1169357161
# Params > coef: 19.61 / bias: 4.90
# Loss Difference between Successive Epochs: 1.995 %
# ========== Epoch 19/100 ==========
# Loss > 4.0733695558
# Params > coef: 19.67 / bias: 4.90
# Loss Difference between Successive Epochs: 1.058 %
# ========== Epoch 20/100 ==========
# Loss > 4.0370782974
# Params > coef: 19.72 / bias: 4.92
# Loss Difference between Successive Epochs: 0.891 %
# Training Ends...
#
# Trained with 100 epochs, 0.1 learning rate
# Time Cost: 0.23664 sec

# %%
# Test 2
X, y = model.data_generation_quad(true_a=20, true_b=5)

n_epochs, lr, batch_size = 100, 1e-1, 1000

start_time = time.time()

model.run(X, y, train=True, n_epochs=n_epochs, lr=lr, batch_size=batch_size)
loss = model.compute_loss(X, y)

end_time = time.time()

print("Training Ends...")
print()
print("Trained with {} epochs, {} learning rate".format(n_epochs, lr))
print("Time Cost: {:.5f} sec".format(end_time-start_time))
# Out:
# Training Starts...
# Mini-Batch SGD w Batch Size: 1000
# ========== Epoch 1/100 ==========
# Loss > 460442.1422585119
# Params > coef: 65.66 / bias: 89.31
# Loss Difference between Successive Epochs: 99.54 %
# ========== Epoch 2/100 ==========
# Loss > 411795.3013356184
# Params > coef: 103.80 / bias: 154.32
# Loss Difference between Successive Epochs: 10.565 %
# ========== Epoch 3/100 ==========
# Loss > 384816.1042081551
# Params > coef: 111.20 / bias: 206.12
# Loss Difference between Successive Epochs: 6.552 %
# ========== Epoch 4/100 ==========
# Loss > 361607.6422110149
# Params > coef: 131.44 / bias: 257.06
# Loss Difference between Successive Epochs: 6.031 %
# ========== Epoch 5/100 ==========
# Loss > 347229.5146669057
# Params > coef: 153.15 / bias: 296.07
# Loss Difference between Successive Epochs: 3.976 %
# ========== Epoch 6/100 ==========
# Loss > 340279.8681946677
# Params > coef: 166.20 / bias: 320.56
# Loss Difference between Successive Epochs: 2.001 %
# ========== Epoch 7/100 ==========
# Loss > 335929.6520689180
# Params > coef: 173.04 / bias: 340.71
# Loss Difference between Successive Epochs: 1.278 %
# ========== Epoch 8/100 ==========
# Loss > 332726.5796240324
# Params > coef: 178.74 / bias: 359.46
# Loss Difference between Successive Epochs: 0.953 %
# Training Ends...
#
# Trained with 100 epochs, 0.1 learning rate
# Time Cost: 0.17843 sec

# %%
# ----- 참고 -----
# - 직전 epoch와의 loss difference를 계산하는 코드와 100 epoch동안의 Loss값을 기록하여 그래프로 나타내는 코드를 삽입하였다.
# - loss difference의 결과값은 '(직전 loss - 현재 loss) / 직전 loss * 100'으로 계산하였고, Loss Difference between Successive Epochs'로 값을 출력하였다.
# - SGD optimal loss value의 기준이 적절한가?
#     - SGD의 경우 Loss의 증감이 반복되기 때문에 loss difference가 1%미만할 때의 loss를 optimal이라고 하는 것보다는 loss가 특정 값 아래일 때 학습을 중단하고 그 지점에서의 loss를 optimal이라고 한다면, 다른 결과가 나왔을 수 있을 것 같다.
#     - 그러나 우선, 문제에서 요구한 것처럼 optimal loss value를 loss difference가 1% 미만이 되는 지점에서의 loss로 지정하였다.
